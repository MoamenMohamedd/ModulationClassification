# %% [markdown]
# # Assignment 3 Modulation Recognition
# ---

# %% [markdown]
# ### 1) Download data
# ---

# %%
#Mount the google drive to manage files
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
cd gdrive/My\ Drive/Colab\ Notebooks
# Out:
# /content/gdrive/My Drive/Colab Notebooks

# %%
#Downloading the dataset for the first time to the drive
# !wget http://opendata.deepsig.io/datasets/2016.10/RML2016.10b.tar.bz2
# Out:
# --2019-04-30 15:25:44--  http://opendata.deepsig.io/datasets/2016.10/RML2016.10b.tar.bz2
# Resolving opendata.deepsig.io (opendata.deepsig.io)... 52.14.91.165
# Connecting to opendata.deepsig.io (opendata.deepsig.io)|52.14.91.165|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1245608913 (1.2G) [application/x-bzip2]
# Saving to: ‘RML2016.10b.tar.bz2’
#
# RML2016.10b.tar.bz2 100%[===================>]   1.16G  13.4MB/s    in 81s
#
# 2019-04-30 15:27:05 (14.7 MB/s) - ‘RML2016.10b.tar.bz2’ saved [1245608913/1245608913]

# %%
#Extracting the file for the first time
# !tar xjf "RML2016.10b.tar.bz2"

# %%
import numpy as np
import pickle
from keras.models import Sequential
from keras.layers import Dense,Reshape,Flatten,Dropout
from sklearn import preprocessing
from scipy.integrate import cumtrapz
from keras.callbacks import EarlyStopping
from keras.layers.convolutional import Conv2D
import pandas as pd
from string import atoi
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
# Load the dataset
# Xd = pickle.load(open("RML2016.10b.dat",'rb'))

# snrs,mods = map(lambda j: sorted(list(set(map(lambda x: x[j], Xd.keys())))), [1,0])
# X = []  
# lbl = []
# for mod in mods:
#     for snr in snrs:
#          X.append(Xd[(mod,snr)])
#          for i in range(Xd[(mod,snr)].shape[0]):  
#           lbl.append(np.array([mod,snr]))
# X = np.vstack(X)

# labels = np.asarray(lbl)
# #Save the labels to easily manage the memory
# np.save('labels' , labels)

# %% [markdown]
# ## 2) Create feature spaces
# --

# %%
#Additional feature spaces

#Evaluating the differentiation and integration of the signals then saving the arrays

#X_diff=np.apply_along_axis(np.gradient, 1, data)
#X_integ=np.apply_along_axis(cumtrapz, 1, data, initial=0)
#np.save('X_diff',X_diff)
#np.save('X_integ',X_integ)
#X_diff=np.load('X_diff.npy')
#X_integ=np.load('X_integ.npy')

# %%
#Combining all the features together

# newDataset = []

# for i in range(0,data.shape[0]):
#   newDataset.append(np.vstack((X[i], X_diff[i] , X_integ[i])))
  
# newDataset = np.array(newDataset)

# %% [markdown]
# ##3) Supervised learning step

# %%
#Load the saved files
X_rawdiffinteg = np.load('X_rawdiffinteg.npy')
labels = pd.DataFrame(np.load('labels.npy') , columns=['mod', 'snr'])

# %%
#Binarize the modulation types for the models
lb = preprocessing.LabelBinarizer()
binarized_labels = lb.fit_transform(labels['mod'])

temp = []
for row in binarized_labels:
  temp.append(tuple(row))
  

labels['mod'] = temp

# %%
#Splitting the dataset 50 50
training_set,test_set,training_set_labels,test_set_labels = train_test_split(X_rawdiffinteg, labels, test_size=0.5,shuffle=True ,random_state=42)

# training_set = X_rawdiffinteg[1::2]
# test_set = X_rawdiffinteg[0::2]
# training_set_labels = labels.iloc[1::2]
# test_set_labels = labels.iloc[0::2]

#Adjusting the labels for the confusion matrix and splitting the test set according to the snr

print training_set.shape , test_set.shape
print training_set_labels.shape , test_set_labels.shape

class SnrTestGroup:
  def __init__(self, test_set, test_set_labels):
    self.test_set = test_set
    self.test_set_labels =test_set_labels

label_groups = test_set_labels.groupby('snr')
label_groups_indices = label_groups.groups


test_sets_dict = {}

for name,group in label_groups:
  test_sets_dict[name] = SnrTestGroup( X_rawdiffinteg[label_groups_indices[name].tolist()] , group)
  

# for value , snr in zip(test_sets_dict.values() , test_sets_dict.keys()):
#   print snr
#   print value.test_set
#   print value.test_set_labels



training_set_labels = np.asarray(training_set_labels['mod'].tolist())
# Out:
# (600000, 6, 128) (600000, 6, 128)
# (600000, 2) (600000, 2)

# %%
import gc
#Freeing some memory

#del X_rawdiffinteg
#del labels
gc.collect()
# Out:
# 81797

# %%
num_epochs = 150
batch_size = 1024

# %%
def plot_confusion_matrix(cm, title, cmap=plt.cm.Blues):
  labels = ['8PSK','AM-DSB','BPSK','CPFSK','GFSK','PAM4','QAM16','QAM64','QPSK','WBFM']
  plt.imshow(cm, interpolation='nearest', cmap=cmap)
  plt.title(title)
  plt.colorbar()
  tick_marks = np.arange(len(labels))
  plt.xticks(tick_marks, labels, rotation=45)
  plt.yticks(tick_marks, labels)
  plt.tight_layout()
  plt.ylabel('True label')
  plt.xlabel('Predicted label')
    
def adjust(x):
  results = []
  for row in x:
    results.append(np.argmax(row))
  return results 
    

def display_plot(test_labels,predicted_labels,name):
  confusion = confusion_matrix(adjust(test_labels),adjust(predicted_labels))
  normal_confusion = confusion.astype('float') / confusion.sum(axis=1)[:, np.newaxis]
  plt.figure()
  plot_confusion_matrix(normal_confusion,"Confusion matrix for SNR " + name)
  
  
def plot_accuracy(acc,snr):
  plt.figure()
  plt.plot(snr, acc)
  plt.xlabel("Signal to Noise Ratio")
  plt.ylabel("Classification Accuracy")
  plt.title("Classification Accuracy on RadioML 2016.10 Beta")
  print "The average overall accuracy is " + str(np.sum(acc)/float(np.ma.count(acc)))

# %%
def fully_conn_model(training_set , test_set , training_labels , test_labels,name):
  # Create a fully connected model
  model = Sequential()

  model.add(Reshape((training_set.shape[1]*training_set.shape[2],),input_shape=(training_set.shape[1],training_set.shape[2])))
  model.add(Dense(512, init='uniform', activation='relu'))
  model.add(Dense(256, init='uniform', activation='relu'))
  model.add(Dense(10, init='uniform', activation='softmax'))

  # Compile model
  model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

  # Display layers
  model.summary()

  # Fit the model
  model.fit(training_set, training_set_labels, epochs=10, batch_size=1024, validation_split=0.05, verbose = 2,
            callbacks=[EarlyStopping(monitor='val_loss',patience=10,verbose=1, mode='min')])

  # Evaluate performance
  score = model.evaluate(test_set, test_labels, verbose=1, batch_size=batch_size)
  print 'score is ' , score[0] , 'classification accuracy is ' , score[1]*100
  
  #plot
  predicted_labels = model.predict(test_set,batch_size)
  display_plot(test_labels,predicted_labels,name)
  
  return score[1]

# %%
def cnn_model(training_set , test_set , training_labels , test_labels, name):
  
  # Create a CNN model
  
  model = Sequential()
  model.add(Reshape((training_set.shape[2],training_set.shape[1],1),input_shape=(training_set.shape[1],training_set.shape[2])))
  model.add(Conv2D(filters = 64,kernel_size=(1,3),padding="same", data_format='channels_last', activation='relu'))
  model.add(Dropout(0.5))
  model.add(Conv2D(filters = 16,kernel_size=(2,3),padding="same",data_format='channels_last', activation='relu'))
  model.add(Dropout(0.5))
  model.add(Flatten())
  model.add(Dense(128, init='uniform', activation='relu'))
  model.add(Dense(10, init='uniform', activation='softmax'))

  # Compile model
  model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

  # Display layers
  model.summary()

  # Fit the model
  model.fit(training_set, training_set_labels, epochs=10, batch_size=1024, validation_split=0.05, verbose = 2,
            callbacks=[EarlyStopping(monitor='val_loss',patience=10,verbose=1, mode='min')])

 
  # Evaluate performance
  score = model.evaluate(test_set, test_labels, verbose=1, batch_size=batch_size)
  print 'score is ' , score[0] , 'classification accuracy is ' , score[1]*100
  
  #plot
  predicted_labels = model.predict(test_set,batch_size)
  display_plot(test_labels,predicted_labels,name)

  return score[1]

# %% [markdown]
# ##4) Big picture

# %%
#Running all the models

# Raw features only (fully connected)

accs = []

snrs = []

list1 = [int(x) for x in test_sets_dict.keys()]

list1.sort()

list2 = [str(x) for x in list1]

for snr in list2:
  snr_test_set = test_sets_dict[snr].test_set[:,0:2]
  snr_test_set_labels = np.asarray(test_sets_dict[snr].test_set_labels['mod'].tolist())
  accu=fully_conn_model(training_set[:,0:2],snr_test_set,training_set_labels,snr_test_set_labels,snr)
  accs.append(accu)
  snrs.append(snr)

plot_accuracy(accs,snrs)



# diff features only  (fully connected)

# accs = []

# snrs = []

# list1 = [int(x) for x in test_sets_dict.keys()]

# list1.sort()

# list2 = [str(x) for x in list1]

# print list2

# for snr in list2:
#   snr_test_set = test_sets_dict[snr].test_set[:,2:4]
#   snr_test_set_labels = np.asarray(test_sets_dict[snr].test_set_labels['mod'].tolist())
#   accu=fully_conn_model(training_set[:,2:4],test_set[:,2:4],training_set_labels,test_set_labels,snr)
#   accs.append(accu)
#   snrs.append(snr)

# plot_accuracy(accs,snrs)



# integration features only  (fully connected)
# accs = []

# snrs = []

# list1 = [int(x) for x in test_sets_dict.keys()]

# list1.sort()

# list2 = [str(x) for x in list1]

# print list2

# for snr in list2:
#   snr_test_set = test_sets_dict[snr].test_set[:,4:6]
#   snr_test_set_labels = np.asarray(test_sets_dict[snr].test_set_labels['mod'].tolist())
#   accu=fully_conn_model(training_set[:,4:6],test_set[:,4:6],training_set_labels,test_set_labels,snr)
#   accs.append(accu)
#   snrs.append(snr)

# plot_accuracy(accs,snrs)



# raw + diff + integ (fully connected)

# accs = []

# snrs = []

# list1 = [int(x) for x in test_sets_dict.keys()]

# list1.sort()

# list2 = [str(x) for x in list1]

# print list2

# for snr in list2:
#   snr_test_set = test_sets_dict[snr].test_set
#   snr_test_set_labels = np.asarray(test_sets_dict[snr].test_set_labels['mod'].tolist())
#   accu=fully_conn_model(training_set,test_set,training_set_labels,test_set_labels,snr)
#   accs.append(accu)
#   snrs.append(snr)

# plot_accuracy(accs,snrs)
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:6: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(512, activation="relu", kernel_initializer="uniform")`
#
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:7: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(256, activation="relu", kernel_initializer="uniform")`
#   import sys
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(10, activation="softmax", kernel_initializer="uniform")`
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_23 (Reshape)         (None, 256)               0
# _________________________________________________________________
# dense_66 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dense_67 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dense_68 (Dense)             (None, 10)                2570
# =================================================================
# Total params: 265,482
# Trainable params: 265,482
# Non-trainable params: 0
# _________________________________________________________________
# Train on 570000 samples, validate on 30000 samples
# Epoch 1/10
#  - 8s - loss: 1.9709 - acc: 0.2191 - val_loss: 1.7987 - val_acc: 0.2906
# Epoch 2/10
#  - 5s - loss: 1.7492 - acc: 0.3043 - val_loss: 1.7235 - val_acc: 0.3128
# Epoch 3/10
#  - 5s - loss: 1.6968 - acc: 0.3294 - val_loss: 1.6852 - val_acc: 0.3374
# Epoch 4/10
#  - 5s - loss: 1.6606 - acc: 0.3447 - val_loss: 1.6516 - val_acc: 0.3490
# Epoch 5/10
#  - 5s - loss: 1.6071 - acc: 0.3602 - val_loss: 1.5723 - val_acc: 0.3716
# Epoch 6/10
#  - 5s - loss: 1.5304 - acc: 0.3824 - val_loss: 1.5201 - val_acc: 0.3862
# Epoch 7/10
#  - 5s - loss: 1.4911 - acc: 0.3935 - val_loss: 1.4944 - val_acc: 0.3954
# Epoch 8/10
#  - 5s - loss: 1.4615 - acc: 0.4032 - val_loss: 1.4698 - val_acc: 0.3966
# Epoch 9/10
#  - 5s - loss: 1.4343 - acc: 0.4141 - val_loss: 1.4453 - val_acc: 0.4098
# Epoch 10/10
#  - 5s - loss: 1.4077 - acc: 0.4240 - val_loss: 1.4192 - val_acc: 0.4200
# 30066/30066 [==============================] - 0s 7us/step
# score is  2.431422086197531 classification accuracy is  10.267411696106375
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_24 (Reshape)         (None, 256)               0
# _________________________________________________________________
# dense_69 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dense_70 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dense_71 (Dense)             (None, 10)                2570
# =================================================================
# Total params: 265,482
# Trainable params: 265,482
# Non-trainable params: 0
# _________________________________________________________________
# Train on 570000 samples, validate on 30000 samples
# Epoch 1/10
#  - 7s - loss: 1.9615 - acc: 0.2218 - val_loss: 1.7937 - val_acc: 0.2849
# Epoch 2/10
#  - 5s - loss: 1.7425 - acc: 0.3055 - val_loss: 1.7153 - val_acc: 0.3201
# Epoch 3/10
#  - 5s - loss: 1.6930 - acc: 0.3280 - val_loss: 1.6818 - val_acc: 0.3313
# Epoch 4/10
#  - 6s - loss: 1.6543 - acc: 0.3419 - val_loss: 1.6430 - val_acc: 0.3428
# Epoch 5/10
#  - 6s - loss: 1.5824 - acc: 0.3633 - val_loss: 1.5641 - val_acc: 0.3689
# Epoch 6/10
#  - 5s - loss: 1.5178 - acc: 0.3850 - val_loss: 1.5132 - val_acc: 0.3864
# Epoch 7/10
#  - 5s - loss: 1.4765 - acc: 0.4003 - val_loss: 1.4771 - val_acc: 0.3974
# Epoch 8/10
#  - 5s - loss: 1.4385 - acc: 0.4138 - val_loss: 1.4426 - val_acc: 0.4124
# Epoch 9/10
#  - 5s - loss: 1.3925 - acc: 0.4318 - val_loss: 1.4004 - val_acc: 0.4335
# Epoch 10/10
#  - 5s - loss: 1.3505 - acc: 0.4458 - val_loss: 1.3707 - val_acc: 0.4409
# 29984/29984 [==============================] - 0s 8us/step
# score is  2.428134769869207 classification accuracy is  10.759071503212256
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_25 (Reshape)         (None, 256)               0
# _________________________________________________________________
# dense_72 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dense_73 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dense_74 (Dense)             (None, 10)                2570
# =================================================================
# Total params: 265,482
# Trainable params: 265,482
# Non-trainable params: 0
# _________________________________________________________________
# Train on 570000 samples, validate on 30000 samples
# Epoch 1/10
#  - 7s - loss: 1.9605 - acc: 0.2216 - val_loss: 1.7918 - val_acc: 0.2850
# Epoch 2/10
#  - 5s - loss: 1.7411 - acc: 0.3073 - val_loss: 1.7150 - val_acc: 0.3238
# Epoch 3/10
#  - 5s - loss: 1.6901 - acc: 0.3308 - val_loss: 1.6801 - val_acc: 0.3434
# Epoch 4/10
#  - 5s - loss: 1.6535 - acc: 0.3473 - val_loss: 1.6427 - val_acc: 0.3558
# Epoch 5/10
#  - 5s - loss: 1.5944 - acc: 0.3639 - val_loss: 1.5594 - val_acc: 0.3753
# Epoch 6/10
#  - 5s - loss: 1.5152 - acc: 0.3870 - val_loss: 1.5089 - val_acc: 0.3906
# Epoch 7/10
#  - 5s - loss: 1.4741 - acc: 0.3998 - val_loss: 1.4796 - val_acc: 0.4023
# Epoch 8/10
#  - 6s - loss: 1.4427 - acc: 0.4119 - val_loss: 1.4522 - val_acc: 0.4078
# Epoch 9/10
#  - 6s - loss: 1.4153 - acc: 0.4233 - val_loss: 1.4330 - val_acc: 0.4179
# Epoch 10/10
#  - 5s - loss: 1.3860 - acc: 0.4346 - val_loss: 1.4033 - val_acc: 0.4250
# 30092/30092 [==============================] - 0s 7us/step
# score is  2.3694462469089035 classification accuracy is  11.318622895152616
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_26 (Reshape)         (None, 256)               0
# _________________________________________________________________
# dense_75 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dense_76 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dense_77 (Dense)             (None, 10)                2570
# =================================================================
# Total params: 265,482
# Trainable params: 265,482
# Non-trainable params: 0
# _________________________________________________________________
# Train on 570000 samples, validate on 30000 samples
# Epoch 1/10
#  - 5s - loss: 1.9567 - acc: 0.2230 - val_loss: 1.7844 - val_acc: 0.2901
# Epoch 2/10
#  - 3s - loss: 1.7392 - acc: 0.3077 - val_loss: 1.7108 - val_acc: 0.3192
# Epoch 3/10
#  - 3s - loss: 1.6914 - acc: 0.3303 - val_loss: 1.6770 - val_acc: 0.3382
# Epoch 4/10
#  - 3s - loss: 1.6537 - acc: 0.3443 - val_loss: 1.6368 - val_acc: 0.3509
# Epoch 5/10
#  - 3s - loss: 1.5941 - acc: 0.3601 - val_loss: 1.5651 - val_acc: 0.3743
# Epoch 6/10
#  - 3s - loss: 1.5268 - acc: 0.3823 - val_loss: 1.5196 - val_acc: 0.3905
# Epoch 7/10
#  - 3s - loss: 1.4848 - acc: 0.3970 - val_loss: 1.4869 - val_acc: 0.4001
# Epoch 8/10
#  - 3s - loss: 1.4516 - acc: 0.4092 - val_loss: 1.4582 - val_acc: 0.4111
# Epoch 9/10
#  - 3s - loss: 1.4205 - acc: 0.4217 - val_loss: 1.4306 - val_acc: 0.4175
# Epoch 10/10
#  - 3s - loss: 1.3894 - acc: 0.4346 - val_loss: 1.4121 - val_acc: 0.4162
# 30033/30033 [==============================] - 0s 3us/step
# score is  2.265655384821694 classification accuracy is  13.99793559801637
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_27 (Reshape)         (None, 256)               0
# _________________________________________________________________
# dense_78 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dense_79 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dense_80 (Dense)             (None, 10)                2570
# =================================================================
# Total params: 265,482
# Trainable params: 265,482
# Non-trainable params: 0
# _________________________________________________________________
# Train on 570000 samples, validate on 30000 samples
# Epoch 1/10
#  - 5s - loss: 1.9810 - acc: 0.2166 - val_loss: 1.8077 - val_acc: 0.2808
# Epoch 2/10
#  - 3s - loss: 1.7617 - acc: 0.2975 - val_loss: 1.7303 - val_acc: 0.3155
# Epoch 3/10
#  - 3s - loss: 1.7081 - acc: 0.3226 - val_loss: 1.7018 - val_acc: 0.3311
# Epoch 4/10
#  - 3s - loss: 1.6703 - acc: 0.3357 - val_loss: 1.6547 - val_acc: 0.3432
# Epoch 5/10
#  - 3s - loss: 1.6095 - acc: 0.3533 - val_loss: 1.5755 - val_acc: 0.3701
# Epoch 6/10
#  - 3s - loss: 1.5366 - acc: 0.3783 - val_loss: 1.5262 - val_acc: 0.3875
# Epoch 7/10
#  - 3s - loss: 1.4949 - acc: 0.3912 - val_loss: 1.4930 - val_acc: 0.3933
# Epoch 8/10
#  - 3s - loss: 1.4631 - acc: 0.4017 - val_loss: 1.4665 - val_acc: 0.4007
# Epoch 9/10
#  - 3s - loss: 1.4349 - acc: 0.4113 - val_loss: 1.4436 - val_acc: 0.4129
# Epoch 10/10
#  - 3s - loss: 1.4050 - acc: 0.4221 - val_loss: 1.4226 - val_acc: 0.4076
# 29998/29998 [==============================] - 0s 3us/step
# score is  2.191257720661526 classification accuracy is  14.267617845759407
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_28 (Reshape)         (None, 256)               0
# _________________________________________________________________
# dense_81 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dense_82 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dense_83 (Dense)             (None, 10)                2570
# =================================================================
# Total params: 265,482
# Trainable params: 265,482
# Non-trainable params: 0
# _________________________________________________________________
# Train on 570000 samples, validate on 30000 samples
# Epoch 1/10
#  - 4s - loss: 1.9559 - acc: 0.2247 - val_loss: 1.7767 - val_acc: 0.2873
# Epoch 2/10
#  - 3s - loss: 1.7318 - acc: 0.3113 - val_loss: 1.7061 - val_acc: 0.3198
# Epoch 3/10
#  - 3s - loss: 1.6825 - acc: 0.3358 - val_loss: 1.6733 - val_acc: 0.3469
# Epoch 4/10
#  - 3s - loss: 1.6477 - acc: 0.3502 - val_loss: 1.6398 - val_acc: 0.3519
# Epoch 5/10
#  - 3s - loss: 1.5993 - acc: 0.3632 - val_loss: 1.5787 - val_acc: 0.3688
# Epoch 6/10
#  - 3s - loss: 1.5298 - acc: 0.3844 - val_loss: 1.5196 - val_acc: 0.3884
# Epoch 7/10
#  - 3s - loss: 1.4814 - acc: 0.3977 - val_loss: 1.4828 - val_acc: 0.3952
# Epoch 8/10
#  - 3s - loss: 1.4494 - acc: 0.4081 - val_loss: 1.4568 - val_acc: 0.4025
# Epoch 9/10
#  - 3s - loss: 1.4210 - acc: 0.4189 - val_loss: 1.4340 - val_acc: 0.4109
# Epoch 10/10
#  - 3s - loss: 1.3924 - acc: 0.4306 - val_loss: 1.4275 - val_acc: 0.4079
# 30081/30081 [==============================] - 0s 3us/step
# score is  1.9734082689334735 classification accuracy is  22.76852499106745
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_29 (Reshape)         (None, 256)               0
# _________________________________________________________________
# dense_84 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dense_85 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dense_86 (Dense)             (None, 10)                2570
# =================================================================
# Total params: 265,482
# Trainable params: 265,482
# Non-trainable params: 0
# _________________________________________________________________
# Train on 570000 samples, validate on 30000 samples
# Epoch 1/10
#  - 4s - loss: 1.9681 - acc: 0.2208 - val_loss: 1.7971 - val_acc: 0.2829
# Epoch 2/10
#  - 3s - loss: 1.7463 - acc: 0.3040 - val_loss: 1.7197 - val_acc: 0.3205
# Epoch 3/10
#  - 3s - loss: 1.6860 - acc: 0.3312 - val_loss: 1.6615 - val_acc: 0.3420
# Epoch 4/10
#  - 3s - loss: 1.6296 - acc: 0.3480 - val_loss: 1.6114 - val_acc: 0.3573
# Epoch 5/10
#  - 3s - loss: 1.5692 - acc: 0.3672 - val_loss: 1.5497 - val_acc: 0.3771
# Epoch 6/10
#  - 3s - loss: 1.5155 - acc: 0.3859 - val_loss: 1.5150 - val_acc: 0.3878
# Epoch 7/10
#  - 3s - loss: 1.4812 - acc: 0.3974 - val_loss: 1.4860 - val_acc: 0.3984
# Epoch 8/10
#  - 3s - loss: 1.4522 - acc: 0.4078 - val_loss: 1.4594 - val_acc: 0.4075
# Epoch 9/10
#  - 3s - loss: 1.4235 - acc: 0.4176 - val_loss: 1.4361 - val_acc: 0.4172
# Epoch 10/10
#  - 3s - loss: 1.3940 - acc: 0.4291 - val_loss: 1.4068 - val_acc: 0.4248
# 30020/30020 [==============================] - 0s 3us/step
# score is  1.7054175670586929 classification accuracy is  28.44103930712858
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_30 (Reshape)         (None, 256)               0
# _________________________________________________________________
# dense_87 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dense_88 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dense_89 (Dense)             (None, 10)                2570
# =================================================================
# Total params: 265,482
# Trainable params: 265,482
# Non-trainable params: 0
# _________________________________________________________________
# Train on 570000 samples, validate on 30000 samples
# Epoch 1/10
#  - 6s - loss: 1.9614 - acc: 0.2221 - val_loss: 1.7921 - val_acc: 0.2896
# Epoch 2/10
#  - 5s - loss: 1.7399 - acc: 0.3075 - val_loss: 1.7106 - val_acc: 0.3260
# Epoch 3/10
#  - 5s - loss: 1.6890 - acc: 0.3309 - val_loss: 1.6790 - val_acc: 0.3341
# Epoch 4/10
#  - 5s - loss: 1.6531 - acc: 0.3438 - val_loss: 1.6403 - val_acc: 0.3494
# Epoch 5/10
#  - 6s - loss: 1.5949 - acc: 0.3603 - val_loss: 1.5646 - val_acc: 0.3741
# Epoch 6/10
#  - 6s - loss: 1.5233 - acc: 0.3837 - val_loss: 1.5174 - val_acc: 0.3896
# Epoch 7/10
#  - 5s - loss: 1.4808 - acc: 0.3987 - val_loss: 1.4844 - val_acc: 0.3934
# Epoch 8/10
#  - 5s - loss: 1.4492 - acc: 0.4103 - val_loss: 1.4622 - val_acc: 0.3966
# Epoch 9/10
#  - 5s - loss: 1.4209 - acc: 0.4211 - val_loss: 1.4390 - val_acc: 0.4131
# Epoch 10/10
#  - 5s - loss: 1.3920 - acc: 0.4329 - val_loss: 1.4087 - val_acc: 0.4248
# 29848/29848 [==============================] - 0s 7us/step
# score is  1.4688033293668081 classification accuracy is  34.68909139800602
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_31 (Reshape)         (None, 256)               0
# _________________________________________________________________
# dense_90 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dense_91 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dense_92 (Dense)             (None, 10)                2570
# =================================================================
# Total params: 265,482
# Trainable params: 265,482
# Non-trainable params: 0
# _________________________________________________________________
# Train on 570000 samples, validate on 30000 samples
# Epoch 1/10
#  - 8s - loss: 1.9891 - acc: 0.2106 - val_loss: 1.8401 - val_acc: 0.2664
# Epoch 2/10
#  - 5s - loss: 1.7790 - acc: 0.2906 - val_loss: 1.7468 - val_acc: 0.3041
# Epoch 3/10
#  - 5s - loss: 1.7191 - acc: 0.3150 - val_loss: 1.7029 - val_acc: 0.3241
# Epoch 4/10
#  - 5s - loss: 1.6697 - acc: 0.3333 - val_loss: 1.6475 - val_acc: 0.3386
# Epoch 5/10
#  - 5s - loss: 1.5898 - acc: 0.3571 - val_loss: 1.5628 - val_acc: 0.3650
# Epoch 6/10
#  - 5s - loss: 1.5312 - acc: 0.3769 - val_loss: 1.5229 - val_acc: 0.3808
# Epoch 7/10
#  - 5s - loss: 1.4934 - acc: 0.3917 - val_loss: 1.4906 - val_acc: 0.3945
# Epoch 8/10
#  - 5s - loss: 1.4610 - acc: 0.4041 - val_loss: 1.4642 - val_acc: 0.3989
# Epoch 9/10
#  - 5s - loss: 1.4295 - acc: 0.4155 - val_loss: 1.4505 - val_acc: 0.4066
# Epoch 10/10
#  - 6s - loss: 1.3936 - acc: 0.4290 - val_loss: 1.3986 - val_acc: 0.4271
# 30033/30033 [==============================] - 0s 8us/step
# score is  1.1513883133286724 classification accuracy is  47.9605767108723
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_32 (Reshape)         (None, 256)               0
# _________________________________________________________________
# dense_93 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dense_94 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dense_95 (Dense)             (None, 10)                2570
# =================================================================
# Total params: 265,482
# Trainable params: 265,482
# Non-trainable params: 0
# _________________________________________________________________
# Train on 570000 samples, validate on 30000 samples
# Epoch 1/10
#  - 8s - loss: 1.9627 - acc: 0.2202 - val_loss: 1.7960 - val_acc: 0.2864
# Epoch 2/10
#  - 5s - loss: 1.7430 - acc: 0.3063 - val_loss: 1.7107 - val_acc: 0.3260
# Epoch 3/10
#  - 5s - loss: 1.6853 - acc: 0.3330 - val_loss: 1.6703 - val_acc: 0.3398
# Epoch 4/10
#  - 5s - loss: 1.6364 - acc: 0.3495 - val_loss: 1.6177 - val_acc: 0.3550
# Epoch 5/10
#  - 5s - loss: 1.5706 - acc: 0.3698 - val_loss: 1.5487 - val_acc: 0.3772
# Epoch 6/10
#  - 5s - loss: 1.5154 - acc: 0.3861 - val_loss: 1.5138 - val_acc: 0.3845
# Epoch 7/10
#  - 5s - loss: 1.4838 - acc: 0.3963 - val_loss: 1.4901 - val_acc: 0.3979
# Epoch 8/10
#  - 5s - loss: 1.4572 - acc: 0.4062 - val_loss: 1.4644 - val_acc: 0.4078
# Epoch 9/10
#  - 5s - loss: 1.4299 - acc: 0.4163 - val_loss: 1.4403 - val_acc: 0.4146
# Epoch 10/10
#  - 5s - loss: 1.3990 - acc: 0.4275 - val_loss: 1.4101 - val_acc: 0.4257
# 30131/30131 [==============================] - 0s 7us/step
# score is  0.9899047451170262 classification accuracy is  58.816501285468725
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_33 (Reshape)         (None, 256)               0
# _________________________________________________________________
# dense_96 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dense_97 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dense_98 (Dense)             (None, 10)                2570
# =================================================================
# Total params: 265,482
# Trainable params: 265,482
# Non-trainable params: 0
# _________________________________________________________________
# Train on 570000 samples, validate on 30000 samples
# Epoch 1/10
#  - 5s - loss: 1.9512 - acc: 0.2255 - val_loss: 1.7748 - val_acc: 0.2946
# Epoch 2/10
#  - 5s - loss: 1.7312 - acc: 0.3106 - val_loss: 1.7028 - val_acc: 0.3285
# Epoch 3/10
#  - 5s - loss: 1.6759 - acc: 0.3373 - val_loss: 1.6609 - val_acc: 0.3445
# Epoch 4/10
#  - 6s - loss: 1.6293 - acc: 0.3523 - val_loss: 1.6081 - val_acc: 0.3580
# Epoch 5/10
#  - 5s - loss: 1.5663 - acc: 0.3714 - val_loss: 1.5493 - val_acc: 0.3793
# Epoch 6/10
#  - 5s - loss: 1.5111 - acc: 0.3882 - val_loss: 1.5108 - val_acc: 0.3901
# Epoch 7/10
#  - 5s - loss: 1.4749 - acc: 0.3994 - val_loss: 1.4855 - val_acc: 0.3934
# Epoch 8/10
#  - 5s - loss: 1.4449 - acc: 0.4101 - val_loss: 1.4571 - val_acc: 0.4063
# Epoch 9/10
#  - 5s - loss: 1.4130 - acc: 0.4204 - val_loss: 1.4253 - val_acc: 0.4177
# Epoch 10/10
#  - 6s - loss: 1.3753 - acc: 0.4350 - val_loss: 1.3927 - val_acc: 0.4322
# 29983/29983 [==============================] - 0s 7us/step
# score is  0.8777200941410026 classification accuracy is  64.64996830663175
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_34 (Reshape)         (None, 256)               0
# _________________________________________________________________
# dense_99 (Dense)             (None, 512)               131584
# _________________________________________________________________
# dense_100 (Dense)            (None, 256)               131328
# _________________________________________________________________
# dense_101 (Dense)            (None, 10)                2570
# =================================================================
# Total params: 265,482
# Trainable params: 265,482
# Non-trainable params: 0
# _________________________________________________________________
# Train on 570000 samples, validate on 30000 samples
# Epoch 1/10
#  - 5s - loss: 1.9638 - acc: 0.2205 - val_loss: 1.7945 - val_acc: 0.2881
# Epoch 2/10
#  - 3s - loss: 1.7486 - acc: 0.3027 - val_loss: 1.7136 - val_acc: 0.3254
# Epoch 3/10
#  - 3s - loss: 1.6886 - acc: 0.3308 - val_loss: 1.6695 - val_acc: 0.3416
# Epoch 4/10
#  - 3s - loss: 1.6436 - acc: 0.3456 - val_loss: 1.6255 - val_acc: 0.3533
# Epoch 5/10
#  - 3s - loss: 1.5862 - acc: 0.3613 - val_loss: 1.5584 - val_acc: 0.3758
# Epoch 6/10
#  - 3s - loss: 1.5227 - acc: 0.3835 - val_loss: 1.5160 - val_acc: 0.3869
# Epoch 7/10
#  - 3s - loss: 1.4841 - acc: 0.3963 - val_loss: 1.4893 - val_acc: 0.3973
# Epoch 8/10
#  - 3s - loss: 1.4535 - acc: 0.4072 - val_loss: 1.4620 - val_acc: 0.4097
# Epoch 9/10
#  - 3s - loss: 1.4248 - acc: 0.4183 - val_loss: 1.4388 - val_acc: 0.4107
# Epoch 10/10
#  - 3s - loss: 1.3962 - acc: 0.4286 - val_loss: 1.4108 - val_acc: 0.4206
# 30047/30047 [==============================] - 0s 3us/step
# score is  0.8932533236507187 classification accuracy is  61.114254338247676
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_35 (Reshape)         (None, 256)               0
# _________________________________________________________________
# dense_102 (Dense)            (None, 512)               131584
# _________________________________________________________________
# dense_103 (Dense)            (None, 256)               131328
# _________________________________________________________________
# dense_104 (Dense)            (None, 10)                2570
# =================================================================
# Total params: 265,482
# Trainable params: 265,482
# Non-trainable params: 0
# _________________________________________________________________
# Train on 570000 samples, validate on 30000 samples
# Epoch 1/10
#  - 5s - loss: 1.9701 - acc: 0.2203 - val_loss: 1.7895 - val_acc: 0.2936
# Epoch 2/10
#  - 3s - loss: 1.7445 - acc: 0.3045 - val_loss: 1.7161 - val_acc: 0.3211
# Epoch 3/10
#  - 3s - loss: 1.6901 - acc: 0.3280 - val_loss: 1.6710 - val_acc: 0.3389
# Epoch 4/10
#  - 3s - loss: 1.6320 - acc: 0.3458 - val_loss: 1.6071 - val_acc: 0.3588
# Epoch 5/10
#  - 3s - loss: 1.5576 - acc: 0.3697 - val_loss: 1.5389 - val_acc: 0.3780
# Epoch 6/10
#  - 3s - loss: 1.5070 - acc: 0.3861 - val_loss: 1.5015 - val_acc: 0.3902
# Epoch 7/10
#  - 3s - loss: 1.4697 - acc: 0.4012 - val_loss: 1.4700 - val_acc: 0.4001
# Epoch 8/10
#  - 3s - loss: 1.4397 - acc: 0.4123 - val_loss: 1.4426 - val_acc: 0.4122
# Epoch 9/10
#  - 3s - loss: 1.4118 - acc: 0.4229 - val_loss: 1.4198 - val_acc: 0.4201
# Epoch 10/10
#  - 3s - loss: 1.3783 - acc: 0.4358 - val_loss: 1.3846 - val_acc: 0.4312
# 29839/29839 [==============================] - 0s 3us/step
# score is  0.8737297668234585 classification accuracy is  61.10124332547095
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_36 (Reshape)         (None, 256)               0
# _________________________________________________________________
# dense_105 (Dense)            (None, 512)               131584
# _________________________________________________________________
# dense_106 (Dense)            (None, 256)               131328
# _________________________________________________________________
# dense_107 (Dense)            (None, 10)                2570
# =================================================================
# Total params: 265,482
# Trainable params: 265,482
# Non-trainable params: 0
# _________________________________________________________________
# Train on 570000 samples, validate on 30000 samples
# Epoch 1/10
#  - 5s - loss: 1.9662 - acc: 0.2214 - val_loss: 1.7904 - val_acc: 0.2915
# Epoch 2/10
#  - 5s - loss: 1.7455 - acc: 0.3047 - val_loss: 1.7220 - val_acc: 0.3173
# Epoch 3/10
#  - 5s - loss: 1.6933 - acc: 0.3280 - val_loss: 1.6744 - val_acc: 0.3405
# Epoch 4/10
#  - 5s - loss: 1.6422 - acc: 0.3454 - val_loss: 1.6249 - val_acc: 0.3494
# Epoch 5/10
#  - 5s - loss: 1.5793 - acc: 0.3651 - val_loss: 1.5608 - val_acc: 0.3772
# Epoch 6/10
#  - 5s - loss: 1.5206 - acc: 0.3849 - val_loss: 1.5179 - val_acc: 0.3909
# Epoch 7/10
#  - 5s - loss: 1.4871 - acc: 0.3970 - val_loss: 1.4931 - val_acc: 0.3982
# Epoch 8/10
#  - 5s - loss: 1.4599 - acc: 0.4067 - val_loss: 1.4719 - val_acc: 0.3997
# Epoch 9/10
#  - 5s - loss: 1.4334 - acc: 0.4166 - val_loss: 1.4466 - val_acc: 0.4122
# Epoch 10/10
#  - 5s - loss: 1.4042 - acc: 0.4271 - val_loss: 1.4170 - val_acc: 0.4217
# 30033/30033 [==============================] - 0s 3us/step
# score is  0.9227692486105974 classification accuracy is  57.62328108866224
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_37 (Reshape)         (None, 256)               0
# _________________________________________________________________
# dense_108 (Dense)            (None, 512)               131584
# _________________________________________________________________
# dense_109 (Dense)            (None, 256)               131328
# _________________________________________________________________
# dense_110 (Dense)            (None, 10)                2570
# =================================================================
# Total params: 265,482
# Trainable params: 265,482
# Non-trainable params: 0
# _________________________________________________________________
# Train on 570000 samples, validate on 30000 samples
# Epoch 1/10
#  - 8s - loss: 1.9643 - acc: 0.2206 - val_loss: 1.7985 - val_acc: 0.2841
# Epoch 2/10
#  - 6s - loss: 1.7462 - acc: 0.3043 - val_loss: 1.7149 - val_acc: 0.3220
# Epoch 3/10
#  - 5s - loss: 1.6869 - acc: 0.3296 - val_loss: 1.6679 - val_acc: 0.3409
# Epoch 4/10
#  - 5s - loss: 1.6320 - acc: 0.3455 - val_loss: 1.6100 - val_acc: 0.3479
# Epoch 5/10
#  - 5s - loss: 1.5602 - acc: 0.3674 - val_loss: 1.5422 - val_acc: 0.3755
# Epoch 6/10
#  - 5s - loss: 1.5074 - acc: 0.3864 - val_loss: 1.5063 - val_acc: 0.3900
# Epoch 7/10
#  - 5s - loss: 1.4732 - acc: 0.3988 - val_loss: 1.4860 - val_acc: 0.4011
# Epoch 8/10
#  - 5s - loss: 1.4433 - acc: 0.4102 - val_loss: 1.4578 - val_acc: 0.4057
# Epoch 9/10
#  - 5s - loss: 1.4150 - acc: 0.4195 - val_loss: 1.4300 - val_acc: 0.4206
# Epoch 10/10
#  - 5s - loss: 1.3814 - acc: 0.4328 - val_loss: 1.4043 - val_acc: 0.4313
# 29884/29884 [==============================] - 0s 3us/step
# score is  0.9016693248325619 classification accuracy is  60.61772184987222
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_38 (Reshape)         (None, 256)               0
# _________________________________________________________________
# dense_111 (Dense)            (None, 512)               131584
# _________________________________________________________________
# dense_112 (Dense)            (None, 256)               131328
# _________________________________________________________________
# dense_113 (Dense)            (None, 10)                2570
# =================================================================
# Total params: 265,482
# Trainable params: 265,482
# Non-trainable params: 0
# _________________________________________________________________
# Train on 570000 samples, validate on 30000 samples
# Epoch 1/10
#  - 8s - loss: 1.9574 - acc: 0.2228 - val_loss: 1.7829 - val_acc: 0.2920
# Epoch 2/10
#  - 5s - loss: 1.7358 - acc: 0.3089 - val_loss: 1.7106 - val_acc: 0.3247
# Epoch 3/10
#  - 5s - loss: 1.6850 - acc: 0.3337 - val_loss: 1.6737 - val_acc: 0.3406
# Epoch 4/10
#  - 5s - loss: 1.6481 - acc: 0.3500 - val_loss: 1.6377 - val_acc: 0.3521
# Epoch 5/10
#  - 5s - loss: 1.5829 - acc: 0.3686 - val_loss: 1.5425 - val_acc: 0.3831
# Epoch 6/10
#  - 5s - loss: 1.5052 - acc: 0.3909 - val_loss: 1.4985 - val_acc: 0.3947
# Epoch 7/10
#  - 5s - loss: 1.4662 - acc: 0.4039 - val_loss: 1.4695 - val_acc: 0.4032
# Epoch 8/10
#  - 5s - loss: 1.4332 - acc: 0.4162 - val_loss: 1.4435 - val_acc: 0.4086
# Epoch 9/10
#  - 5s - loss: 1.4002 - acc: 0.4294 - val_loss: 1.4129 - val_acc: 0.4159
# Epoch 10/10
#  - 5s - loss: 1.3637 - acc: 0.4441 - val_loss: 1.3795 - val_acc: 0.4356
# 29950/29950 [==============================] - 0s 3us/step
# score is  0.8757161672127267 classification accuracy is  60.53088482353643
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_39 (Reshape)         (None, 256)               0
# _________________________________________________________________
# dense_114 (Dense)            (None, 512)               131584
# _________________________________________________________________
# dense_115 (Dense)            (None, 256)               131328
# _________________________________________________________________
# dense_116 (Dense)            (None, 10)                2570
# =================================================================
# Total params: 265,482
# Trainable params: 265,482
# Non-trainable params: 0
# _________________________________________________________________
# Train on 570000 samples, validate on 30000 samples
# Epoch 1/10
#  - 8s - loss: 1.9670 - acc: 0.2196 - val_loss: 1.8000 - val_acc: 0.2811
# Epoch 2/10
#  - 5s - loss: 1.7462 - acc: 0.3039 - val_loss: 1.7180 - val_acc: 0.3225
# Epoch 3/10
#  - 5s - loss: 1.6866 - acc: 0.3309 - val_loss: 1.6684 - val_acc: 0.3428
# Epoch 4/10
#  - 5s - loss: 1.6382 - acc: 0.3472 - val_loss: 1.6164 - val_acc: 0.3553
# Epoch 5/10
#  - 5s - loss: 1.5726 - acc: 0.3669 - val_loss: 1.5469 - val_acc: 0.3779
# Epoch 6/10
#  - 5s - loss: 1.5102 - acc: 0.3879 - val_loss: 1.5042 - val_acc: 0.3903
# Epoch 7/10
#  - 5s - loss: 1.4736 - acc: 0.3996 - val_loss: 1.4734 - val_acc: 0.4007
# Epoch 8/10
#  - 5s - loss: 1.4436 - acc: 0.4096 - val_loss: 1.4470 - val_acc: 0.4080
# Epoch 9/10
#  - 5s - loss: 1.4087 - acc: 0.4232 - val_loss: 1.4132 - val_acc: 0.4159
# Epoch 10/10
#  - 5s - loss: 1.3678 - acc: 0.4384 - val_loss: 1.3745 - val_acc: 0.4368
# 30055/30055 [==============================] - 0s 3us/step
# score is  0.8650226636350185 classification accuracy is  61.24771253694969
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_40 (Reshape)         (None, 256)               0
# _________________________________________________________________
# dense_117 (Dense)            (None, 512)               131584
# _________________________________________________________________
# dense_118 (Dense)            (None, 256)               131328
# _________________________________________________________________
# dense_119 (Dense)            (None, 10)                2570
# =================================================================
# Total params: 265,482
# Trainable params: 265,482
# Non-trainable params: 0
# _________________________________________________________________
# Train on 570000 samples, validate on 30000 samples
# Epoch 1/10
#  - 8s - loss: 1.9650 - acc: 0.2214 - val_loss: 1.7889 - val_acc: 0.2870
# Epoch 2/10
#  - 5s - loss: 1.7438 - acc: 0.3057 - val_loss: 1.7180 - val_acc: 0.3171
# Epoch 3/10
#  - 5s - loss: 1.6926 - acc: 0.3312 - val_loss: 1.6808 - val_acc: 0.3417
# Epoch 4/10
#  - 5s - loss: 1.6473 - acc: 0.3473 - val_loss: 1.6278 - val_acc: 0.3519
# Epoch 5/10
#  - 5s - loss: 1.5924 - acc: 0.3625 - val_loss: 1.5728 - val_acc: 0.3714
# Epoch 6/10
#  - 6s - loss: 1.5306 - acc: 0.3837 - val_loss: 1.5214 - val_acc: 0.3870
# Epoch 7/10
#  - 5s - loss: 1.4889 - acc: 0.3964 - val_loss: 1.4911 - val_acc: 0.3991
# Epoch 8/10
#  - 5s - loss: 1.4581 - acc: 0.4067 - val_loss: 1.4682 - val_acc: 0.3995
# Epoch 9/10
#  - 5s - loss: 1.4303 - acc: 0.4170 - val_loss: 1.4487 - val_acc: 0.4158
# Epoch 10/10
#  - 5s - loss: 1.4026 - acc: 0.4282 - val_loss: 1.4183 - val_acc: 0.4237
# 29828/29828 [==============================] - 0s 3us/step
# score is  0.934785293608772 classification accuracy is  58.80716106791558
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_41 (Reshape)         (None, 256)               0
# _________________________________________________________________
# dense_120 (Dense)            (None, 512)               131584
# _________________________________________________________________
# dense_121 (Dense)            (None, 256)               131328
# _________________________________________________________________
# dense_122 (Dense)            (None, 10)                2570
# =================================================================
# Total params: 265,482
# Trainable params: 265,482
# Non-trainable params: 0
# _________________________________________________________________
# Train on 570000 samples, validate on 30000 samples
# Epoch 1/10
#  - 8s - loss: 1.9593 - acc: 0.2227 - val_loss: 1.7934 - val_acc: 0.2916
# Epoch 2/10
#  - 5s - loss: 1.7429 - acc: 0.3051 - val_loss: 1.7154 - val_acc: 0.3222
# Epoch 3/10
#  - 5s - loss: 1.6864 - acc: 0.3312 - val_loss: 1.6735 - val_acc: 0.3382
# Epoch 4/10
#  - 5s - loss: 1.6434 - acc: 0.3464 - val_loss: 1.6255 - val_acc: 0.3511
# Epoch 5/10
#  - 5s - loss: 1.5781 - acc: 0.3646 - val_loss: 1.5495 - val_acc: 0.3782
# Epoch 6/10
#  - 5s - loss: 1.5125 - acc: 0.3857 - val_loss: 1.4990 - val_acc: 0.3944
# Epoch 7/10
#  - 5s - loss: 1.4701 - acc: 0.4003 - val_loss: 1.4655 - val_acc: 0.4039
# Epoch 8/10
#  - 5s - loss: 1.4381 - acc: 0.4121 - val_loss: 1.4438 - val_acc: 0.4128
# Epoch 9/10
#  - 5s - loss: 1.4099 - acc: 0.4233 - val_loss: 1.4173 - val_acc: 0.4209
# Epoch 10/10
#  - 5s - loss: 1.3809 - acc: 0.4347 - val_loss: 1.3889 - val_acc: 0.4306
# 30013/30013 [==============================] - 0s 5us/step
# score is  0.9085157255145657 classification accuracy is  58.94445741768024
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_42 (Reshape)         (None, 256)               0
# _________________________________________________________________
# dense_123 (Dense)            (None, 512)               131584
# _________________________________________________________________
# dense_124 (Dense)            (None, 256)               131328
# _________________________________________________________________
# dense_125 (Dense)            (None, 10)                2570
# =================================================================
# Total params: 265,482
# Trainable params: 265,482
# Non-trainable params: 0
# _________________________________________________________________
# Train on 570000 samples, validate on 30000 samples
# Epoch 1/10
#  - 8s - loss: 1.9482 - acc: 0.2250 - val_loss: 1.7762 - val_acc: 0.2987
# Epoch 2/10
#  - 5s - loss: 1.7313 - acc: 0.3109 - val_loss: 1.7138 - val_acc: 0.3255
# Epoch 3/10
#  - 5s - loss: 1.6826 - acc: 0.3344 - val_loss: 1.6733 - val_acc: 0.3446
# Epoch 4/10
#  - 5s - loss: 1.6489 - acc: 0.3476 - val_loss: 1.6399 - val_acc: 0.3508
# Epoch 5/10
#  - 5s - loss: 1.5973 - acc: 0.3614 - val_loss: 1.5725 - val_acc: 0.3718
# Epoch 6/10
#  - 5s - loss: 1.5255 - acc: 0.3841 - val_loss: 1.5187 - val_acc: 0.3831
# Epoch 7/10
#  - 5s - loss: 1.4827 - acc: 0.3976 - val_loss: 1.4842 - val_acc: 0.3988
# Epoch 8/10
#  - 5s - loss: 1.4508 - acc: 0.4086 - val_loss: 1.4599 - val_acc: 0.4085
# Epoch 9/10
#  - 5s - loss: 1.4201 - acc: 0.4202 - val_loss: 1.4308 - val_acc: 0.4210
# Epoch 10/10
#  - 5s - loss: 1.3852 - acc: 0.4340 - val_loss: 1.3979 - val_acc: 0.4242
# 30082/30082 [==============================] - 0s 3us/step
# score is  0.9138016927892972 classification accuracy is  57.53274383391799
# The average overall accuracy is 0.42772791090983747

# %%
# Raw features only (cnn)
 
accs = []

snrs = []

list1 = [int(x) for x in test_sets_dict.keys()]

list1.sort()

list2 = [str(x) for x in list1]

for snr in list2:
  snr_test_set = test_sets_dict[snr].test_set[:,0:2]
  snr_test_set_labels = np.asarray(test_sets_dict[snr].test_set_labels['mod'].tolist())
  accu=cnn_model(training_set[:,0:2],snr_test_set,training_set_labels,snr_test_set_labels,snr)
  accs.append(accu)
  snrs.append(snr)

plot_accuracy(accs,snrs)




# diff features only  (fully connected)

# accs = []

# snrs = []

# list1 = [int(x) for x in test_sets_dict.keys()]

# list1.sort()

# list2 = [str(x) for x in list1]

# print list2

# for snr in list2:
#   snr_test_set = test_sets_dict[snr].test_set[:,2:4]
#   snr_test_set_labels = np.asarray(test_sets_dict[snr].test_set_labels['mod'].tolist())
#   accu=cnn_model(training_set[:,2:4],test_set[:,2:4],training_set_labels,test_set_labels,snr)
#   accs.append(accu)
#   snrs.append(snr)

# plot_accuracy(accs,snrs)



# integration features only  (fully connected)
# accs = []

# snrs = []

# list1 = [int(x) for x in test_sets_dict.keys()]

# list1.sort()

# list2 = [str(x) for x in list1]

# print list2

# for snr in list2:
#   snr_test_set = test_sets_dict[snr].test_set[:,4:6]
#   snr_test_set_labels = np.asarray(test_sets_dict[snr].test_set_labels['mod'].tolist())
#   accu=cnn_model(training_set[:,4:6],test_set[:,4:6],training_set_labels,test_set_labels,snr)
#   accs.append(accu)
#   snrs.append(snr)

# plot_accuracy(accs,snrs)



# raw + diff + integ (fully connected)

# accs = []

# snrs = []

# list1 = [int(x) for x in test_sets_dict.keys()]

# list1.sort()

# list2 = [str(x) for x in list1]

# print list2

# for snr in list2:
#   snr_test_set = test_sets_dict[snr].test_set
#   snr_test_set_labels = np.asarray(test_sets_dict[snr].test_set_labels['mod'].tolist())
#   accu=cnn_model(training_set,test_set,training_set_labels,test_set_labels,snr)
#   accs.append(accu)
#   snrs.append(snr)

# plot_accuracy(accs,snrs)
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:12: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(128, activation="relu", kernel_initializer="uniform")`
#   if sys.path[0] == '':
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:13: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(10, activation="softmax", kernel_initializer="uniform")`
#   del sys.path[0]
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_43 (Reshape)         (None, 128, 2, 1)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 128, 2, 64)        256
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128, 2, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 128, 2, 16)        6160
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 128, 2, 16)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dense_126 (Dense)            (None, 128)               524416
# _________________________________________________________________
# dense_127 (Dense)            (None, 10)                1290
# =================================================================
# Total params: 532,122
# Trainable params: 532,122
# Non-trainable params: 0
# _________________________________________________________________
# Train on 570000 samples, validate on 30000 samples
# Epoch 1/10
#  - 19s - loss: 1.8925 - acc: 0.2473 - val_loss: 1.6340 - val_acc: 0.3437
# Epoch 2/10
#  - 16s - loss: 1.5525 - acc: 0.3740 - val_loss: 1.4427 - val_acc: 0.4185
# Epoch 3/10
#  - 15s - loss: 1.4323 - acc: 0.4187 - val_loss: 1.3694 - val_acc: 0.4296
# Epoch 4/10
#  - 15s - loss: 1.3858 - acc: 0.4344 - val_loss: 1.3387 - val_acc: 0.4465
# Epoch 5/10
#  - 15s - loss: 1.3504 - acc: 0.4482 - val_loss: 1.2966 - val_acc: 0.4740
# Epoch 6/10
#  - 16s - loss: 1.3219 - acc: 0.4604 - val_loss: 1.2788 - val_acc: 0.4801
# Epoch 7/10
#  - 15s - loss: 1.3060 - acc: 0.4662 - val_loss: 1.2658 - val_acc: 0.4817
# Epoch 8/10
#  - 15s - loss: 1.2918 - acc: 0.4712 - val_loss: 1.2602 - val_acc: 0.4824
# Epoch 9/10
#  - 15s - loss: 1.2818 - acc: 0.4744 - val_loss: 1.2478 - val_acc: 0.4917
# Epoch 10/10
#  - 15s - loss: 1.2716 - acc: 0.4774 - val_loss: 1.2331 - val_acc: 0.4917
# 30066/30066 [==============================] - 0s 12us/step
# score is  2.370334336788269 classification accuracy is  10.62994745216715
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_44 (Reshape)         (None, 128, 2, 1)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 128, 2, 64)        256
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 128, 2, 64)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 128, 2, 16)        6160
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 128, 2, 16)        0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dense_128 (Dense)            (None, 128)               524416
# _________________________________________________________________
# dense_129 (Dense)            (None, 10)                1290
# =================================================================
# Total params: 532,122
# Trainable params: 532,122
# Non-trainable params: 0
# _________________________________________________________________
# Train on 570000 samples, validate on 30000 samples
# Epoch 1/10
#  - 18s - loss: 1.9042 - acc: 0.2412 - val_loss: 1.6669 - val_acc: 0.3223
# Epoch 2/10
#  - 15s - loss: 1.5835 - acc: 0.3602 - val_loss: 1.4523 - val_acc: 0.4115
# Epoch 3/10
#  - 15s - loss: 1.4568 - acc: 0.4100 - val_loss: 1.3979 - val_acc: 0.4330
# Epoch 4/10
#  - 15s - loss: 1.4126 - acc: 0.4255 - val_loss: 1.3456 - val_acc: 0.4432
# Epoch 5/10
#  - 16s - loss: 1.3594 - acc: 0.4463 - val_loss: 1.2963 - val_acc: 0.4764
# Epoch 6/10
#  - 16s - loss: 1.3254 - acc: 0.4588 - val_loss: 1.2786 - val_acc: 0.4659
# Epoch 7/10
#  - 16s - loss: 1.3052 - acc: 0.4649 - val_loss: 1.2700 - val_acc: 0.4833
# Epoch 8/10
#  - 15s - loss: 1.2922 - acc: 0.4698 - val_loss: 1.2587 - val_acc: 0.4774
# Epoch 9/10
#  - 15s - loss: 1.2784 - acc: 0.4748 - val_loss: 1.2282 - val_acc: 0.4958
# Epoch 10/10
#  - 15s - loss: 1.2681 - acc: 0.4791 - val_loss: 1.2272 - val_acc: 0.4898
# 29984/29984 [==============================] - 0s 10us/step
# score is  2.3545097811117754 classification accuracy is  11.052561364471595
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_45 (Reshape)         (None, 128, 2, 1)         0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 128, 2, 64)        256
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 128, 2, 64)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 128, 2, 16)        6160
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 128, 2, 16)        0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dense_130 (Dense)            (None, 128)               524416
# _________________________________________________________________
# dense_131 (Dense)            (None, 10)                1290
# =================================================================
# Total params: 532,122
# Trainable params: 532,122
# Non-trainable params: 0
# _________________________________________________________________
# Train on 570000 samples, validate on 30000 samples
# Epoch 1/10
#  - 18s - loss: 1.9272 - acc: 0.2357 - val_loss: 1.6856 - val_acc: 0.3168
# Epoch 2/10
#  - 15s - loss: 1.5831 - acc: 0.3623 - val_loss: 1.4660 - val_acc: 0.4078
# Epoch 3/10
#  - 15s - loss: 1.4530 - acc: 0.4116 - val_loss: 1.3599 - val_acc: 0.4544
# Epoch 4/10
#  - 15s - loss: 1.3805 - acc: 0.4396 - val_loss: 1.3146 - val_acc: 0.4529
# Epoch 5/10
#  - 15s - loss: 1.3483 - acc: 0.4513 - val_loss: 1.3075 - val_acc: 0.4600
# Epoch 6/10
#  - 15s - loss: 1.3290 - acc: 0.4573 - val_loss: 1.2914 - val_acc: 0.4644
# Epoch 7/10
#  - 15s - loss: 1.3159 - acc: 0.4615 - val_loss: 1.2815 - val_acc: 0.4758
# Epoch 8/10
#  - 15s - loss: 1.3037 - acc: 0.4657 - val_loss: 1.2755 - val_acc: 0.4793
# Epoch 9/10
#  - 15s - loss: 1.2939 - acc: 0.4702 - val_loss: 1.2521 - val_acc: 0.4895
# Epoch 10/10
#  - 15s - loss: 1.2831 - acc: 0.4738 - val_loss: 1.2399 - val_acc: 0.4887
# 30092/30092 [==============================] - 0s 13us/step
# score is  2.309266350457251 classification accuracy is  11.411670880734121
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_46 (Reshape)         (None, 128, 2, 1)         0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 128, 2, 64)        256
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 128, 2, 64)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 128, 2, 16)        6160
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 128, 2, 16)        0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dense_132 (Dense)            (None, 128)               524416
# _________________________________________________________________
# dense_133 (Dense)            (None, 10)                1290
# =================================================================
# Total params: 532,122
# Trainable params: 532,122
# Non-trainable params: 0
# _________________________________________________________________
# Train on 570000 samples, validate on 30000 samples
# Epoch 1/10
#  - 19s - loss: 1.9167 - acc: 0.2377 - val_loss: 1.6597 - val_acc: 0.3188
# Epoch 2/10
#  - 15s - loss: 1.5919 - acc: 0.3552 - val_loss: 1.4393 - val_acc: 0.4144
# Epoch 3/10
#  - 15s - loss: 1.4320 - acc: 0.4222 - val_loss: 1.3662 - val_acc: 0.4515
# Epoch 4/10
#  - 16s - loss: 1.3752 - acc: 0.4436 - val_loss: 1.3206 - val_acc: 0.4682
# Epoch 5/10
#  - 15s - loss: 1.3474 - acc: 0.4520 - val_loss: 1.3025 - val_acc: 0.4653
# Epoch 6/10
#  - 16s - loss: 1.3284 - acc: 0.4583 - val_loss: 1.2819 - val_acc: 0.4747
# Epoch 7/10
#  - 15s - loss: 1.3151 - acc: 0.4627 - val_loss: 1.2731 - val_acc: 0.4762
# Epoch 8/10
#  - 15s - loss: 1.3013 - acc: 0.4672 - val_loss: 1.2606 - val_acc: 0.4802
# Epoch 9/10
#  - 15s - loss: 1.2899 - acc: 0.4711 - val_loss: 1.2610 - val_acc: 0.4764
# Epoch 10/10
#  - 15s - loss: 1.2774 - acc: 0.4751 - val_loss: 1.2409 - val_acc: 0.4922
# 30033/30033 [==============================] - 0s 12us/step
# score is  2.2373385057381703 classification accuracy is  14.037891646363187
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_47 (Reshape)         (None, 128, 2, 1)         0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 128, 2, 64)        256
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 128, 2, 64)        0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 128, 2, 16)        6160
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 128, 2, 16)        0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dense_134 (Dense)            (None, 128)               524416
# _________________________________________________________________
# dense_135 (Dense)            (None, 10)                1290
# =================================================================
# Total params: 532,122
# Trainable params: 532,122
# Non-trainable params: 0
# _________________________________________________________________
# Train on 570000 samples, validate on 30000 samples
# Epoch 1/10
#  - 21s - loss: 1.9039 - acc: 0.2421 - val_loss: 1.6816 - val_acc: 0.3207
# Epoch 2/10
#  - 15s - loss: 1.5701 - acc: 0.3677 - val_loss: 1.4434 - val_acc: 0.4100
# Epoch 3/10
#  - 15s - loss: 1.4590 - acc: 0.4091 - val_loss: 1.4086 - val_acc: 0.4245
# Epoch 4/10
#  - 15s - loss: 1.4292 - acc: 0.4199 - val_loss: 1.3911 - val_acc: 0.4401
# Epoch 5/10
#  - 15s - loss: 1.3924 - acc: 0.4355 - val_loss: 1.3341 - val_acc: 0.4459
# Epoch 6/10
#  - 16s - loss: 1.3503 - acc: 0.4524 - val_loss: 1.3068 - val_acc: 0.4699
# Epoch 7/10
#  - 15s - loss: 1.3274 - acc: 0.4605 - val_loss: 1.2795 - val_acc: 0.4848
# Epoch 8/10
#  - 15s - loss: 1.3082 - acc: 0.4669 - val_loss: 1.2816 - val_acc: 0.4789
# Epoch 9/10
#  - 15s - loss: 1.2945 - acc: 0.4712 - val_loss: 1.2616 - val_acc: 0.4813
# Epoch 10/10
#  - 15s - loss: 1.2820 - acc: 0.4745 - val_loss: 1.2429 - val_acc: 0.4913
# 29998/29998 [==============================] - 0s 11us/step
# score is  2.1323857261972576 classification accuracy is  17.024468301463042
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_48 (Reshape)         (None, 128, 2, 1)         0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 128, 2, 64)        256
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 128, 2, 64)        0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 128, 2, 16)        6160
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 128, 2, 16)        0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dense_136 (Dense)            (None, 128)               524416
# _________________________________________________________________
# dense_137 (Dense)            (None, 10)                1290
# =================================================================
# Total params: 532,122
# Trainable params: 532,122
# Non-trainable params: 0
# _________________________________________________________________
# Train on 570000 samples, validate on 30000 samples
# Epoch 1/10
#  - 21s - loss: 1.9077 - acc: 0.2423 - val_loss: 1.6456 - val_acc: 0.3310
# Epoch 2/10
#  - 18s - loss: 1.5619 - acc: 0.3725 - val_loss: 1.4419 - val_acc: 0.4205
# Epoch 3/10
#  - 18s - loss: 1.4480 - acc: 0.4156 - val_loss: 1.3764 - val_acc: 0.4381
# Epoch 4/10
#  - 18s - loss: 1.3965 - acc: 0.4339 - val_loss: 1.3353 - val_acc: 0.4582
# Epoch 5/10
#  - 18s - loss: 1.3655 - acc: 0.4452 - val_loss: 1.3142 - val_acc: 0.4658
# Epoch 6/10
#  - 18s - loss: 1.3383 - acc: 0.4558 - val_loss: 1.2900 - val_acc: 0.4749
# Epoch 7/10
#  - 18s - loss: 1.3116 - acc: 0.4640 - val_loss: 1.2582 - val_acc: 0.4873
# Epoch 8/10
#  - 18s - loss: 1.2905 - acc: 0.4712 - val_loss: 1.2429 - val_acc: 0.4828
# Epoch 9/10
#  - 18s - loss: 1.2752 - acc: 0.4762 - val_loss: 1.2473 - val_acc: 0.4858
# Epoch 10/10
#  - 18s - loss: 1.2637 - acc: 0.4801 - val_loss: 1.2138 - val_acc: 0.4984
# 30081/30081 [==============================] - 1s 17us/step
# score is  1.9138208587239158 classification accuracy is  26.418669576249552
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_49 (Reshape)         (None, 128, 2, 1)         0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 128, 2, 64)        256
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 128, 2, 64)        0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 128, 2, 16)        6160
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 128, 2, 16)        0
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dense_138 (Dense)            (None, 128)               524416
# _________________________________________________________________
# dense_139 (Dense)            (None, 10)                1290
# =================================================================
# Total params: 532,122
# Trainable params: 532,122
# Non-trainable params: 0
# _________________________________________________________________
# Train on 570000 samples, validate on 30000 samples
# Epoch 1/10
#  - 21s - loss: 1.9173 - acc: 0.2392 - val_loss: 1.6615 - val_acc: 0.3225
# Epoch 2/10
#  - 15s - loss: 1.6034 - acc: 0.3496 - val_loss: 1.4814 - val_acc: 0.4153
# Epoch 3/10
#  - 15s - loss: 1.4761 - acc: 0.4034 - val_loss: 1.4056 - val_acc: 0.4294
# Epoch 4/10
#  - 15s - loss: 1.3976 - acc: 0.4333 - val_loss: 1.3307 - val_acc: 0.4583
# Epoch 5/10
#  - 16s - loss: 1.3484 - acc: 0.4516 - val_loss: 1.3014 - val_acc: 0.4682
# Epoch 6/10
#  - 15s - loss: 1.3319 - acc: 0.4565 - val_loss: 1.2871 - val_acc: 0.4672
# Epoch 7/10
#  - 15s - loss: 1.3172 - acc: 0.4613 - val_loss: 1.2729 - val_acc: 0.4745
# Epoch 8/10
#  - 15s - loss: 1.3061 - acc: 0.4656 - val_loss: 1.2656 - val_acc: 0.4781
# Epoch 9/10
#  - 15s - loss: 1.2962 - acc: 0.4692 - val_loss: 1.2629 - val_acc: 0.4832
# Epoch 10/10
#  - 16s - loss: 1.2878 - acc: 0.4727 - val_loss: 1.2499 - val_acc: 0.4812
# 30020/30020 [==============================] - 0s 12us/step
# score is  1.665235429601142 classification accuracy is  33.95403065497204
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_50 (Reshape)         (None, 128, 2, 1)         0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 128, 2, 64)        256
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 128, 2, 64)        0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 128, 2, 16)        6160
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 128, 2, 16)        0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 4096)              0
# _________________________________________________________________
# dense_140 (Dense)            (None, 128)               524416
# _________________________________________________________________
# dense_141 (Dense)            (None, 10)                1290
# =================================================================
# Total params: 532,122
# Trainable params: 532,122
# Non-trainable params: 0
# _________________________________________________________________
# Train on 570000 samples, validate on 30000 samples
# Epoch 1/10
#  - 20s - loss: 1.9141 - acc: 0.2386 - val_loss: 1.6569 - val_acc: 0.3206
# Epoch 2/10
#  - 16s - loss: 1.5882 - acc: 0.3585 - val_loss: 1.4720 - val_acc: 0.4051
# Epoch 3/10
#  - 16s - loss: 1.4681 - acc: 0.4065 - val_loss: 1.4084 - val_acc: 0.4313
# Epoch 4/10
#  - 15s - loss: 1.4292 - acc: 0.4197 - val_loss: 1.3798 - val_acc: 0.4360
# Epoch 5/10
#  - 16s - loss: 1.4041 - acc: 0.4288 - val_loss: 1.3554 - val_acc: 0.4364
# Epoch 6/10
#  - 15s - loss: 1.3670 - acc: 0.4430 - val_loss: 1.3103 - val_acc: 0.4648
# Epoch 7/10
#  - 15s - loss: 1.3282 - acc: 0.4576 - val_loss: 1.2816 - val_acc: 0.4737
# Epoch 8/10
#  - 15s - loss: 1.3111 - acc: 0.4633 - val_loss: 1.2681 - val_acc: 0.4802
# Epoch 9/10
#  - 15s - loss: 1.2991 - acc: 0.4677 - val_loss: 1.2577 - val_acc: 0.4796
# Epoch 10/10
#  - 16s - loss: 1.2888 - acc: 0.4711 - val_loss: 1.2479 - val_acc: 0.4876
# 29848/29848 [==============================] - 0s 9us/step
# score is  1.474741601298559 classification accuracy is  39.25891182627764
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_51 (Reshape)         (None, 128, 2, 1)         0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 128, 2, 64)        256
# _________________________________________________________________
# dropout_19 (Dropout)         (None, 128, 2, 64)        0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 128, 2, 16)        6160
# _________________________________________________________________
# dropout_20 (Dropout)         (None, 128, 2, 16)        0
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 4096)              0
# _________________________________________________________________
# dense_142 (Dense)            (None, 128)               524416
# _________________________________________________________________
# dense_143 (Dense)            (None, 10)                1290
# =================================================================
# Total params: 532,122
# Trainable params: 532,122
# Non-trainable params: 0
# _________________________________________________________________
# Train on 570000 samples, validate on 30000 samples
# Epoch 1/10
#  - 19s - loss: 1.9207 - acc: 0.2376 - val_loss: 1.6734 - val_acc: 0.3149
# Epoch 2/10
#  - 16s - loss: 1.5634 - acc: 0.3696 - val_loss: 1.4641 - val_acc: 0.3968
# Epoch 3/10
#  - 16s - loss: 1.4536 - acc: 0.4104 - val_loss: 1.3934 - val_acc: 0.4302
# Epoch 4/10
#  - 15s - loss: 1.4126 - acc: 0.4252 - val_loss: 1.3502 - val_acc: 0.4459
# Epoch 5/10
#  - 16s - loss: 1.3576 - acc: 0.4479 - val_loss: 1.3124 - val_acc: 0.4578
# Epoch 6/10
#  - 15s - loss: 1.3292 - acc: 0.4590 - val_loss: 1.2840 - val_acc: 0.4817
# Epoch 7/10
#  - 15s - loss: 1.3075 - acc: 0.4673 - val_loss: 1.2664 - val_acc: 0.4787
# Epoch 8/10
#  - 15s - loss: 1.2921 - acc: 0.4719 - val_loss: 1.2650 - val_acc: 0.4819
# Epoch 9/10
#  - 16s - loss: 1.2793 - acc: 0.4773 - val_loss: 1.2415 - val_acc: 0.4954
# Epoch 10/10
#  - 16s - loss: 1.2679 - acc: 0.4809 - val_loss: 1.2344 - val_acc: 0.4943
# 30033/30033 [==============================] - 0s 7us/step
# score is  1.1554083737230554 classification accuracy is  50.9173242631335
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_52 (Reshape)         (None, 128, 2, 1)         0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 128, 2, 64)        256
# _________________________________________________________________
# dropout_21 (Dropout)         (None, 128, 2, 64)        0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 128, 2, 16)        6160
# _________________________________________________________________
# dropout_22 (Dropout)         (None, 128, 2, 16)        0
# _________________________________________________________________
# flatten_11 (Flatten)         (None, 4096)              0
# _________________________________________________________________
# dense_144 (Dense)            (None, 128)               524416
# _________________________________________________________________
# dense_145 (Dense)            (None, 10)                1290
# =================================================================
# Total params: 532,122
# Trainable params: 532,122
# Non-trainable params: 0
# _________________________________________________________________
# Train on 570000 samples, validate on 30000 samples
# Epoch 1/10
#  - 22s - loss: 1.9170 - acc: 0.2405 - val_loss: 1.6758 - val_acc: 0.3131
# Epoch 2/10
#  - 18s - loss: 1.5703 - acc: 0.3671 - val_loss: 1.4711 - val_acc: 0.4060
# Epoch 3/10
#  - 18s - loss: 1.4775 - acc: 0.4014 - val_loss: 1.4151 - val_acc: 0.4225
# Epoch 4/10
#  - 18s - loss: 1.4188 - acc: 0.4233 - val_loss: 1.3550 - val_acc: 0.4506
# Epoch 5/10
#  - 18s - loss: 1.3747 - acc: 0.4401 - val_loss: 1.3215 - val_acc: 0.4668
# Epoch 6/10
#  - 18s - loss: 1.3477 - acc: 0.4511 - val_loss: 1.2932 - val_acc: 0.4787
# Epoch 7/10
#  - 18s - loss: 1.3196 - acc: 0.4616 - val_loss: 1.2835 - val_acc: 0.4748
# Epoch 8/10
#  - 18s - loss: 1.3005 - acc: 0.4693 - val_loss: 1.2490 - val_acc: 0.4894
# Epoch 9/10
#  - 18s - loss: 1.2849 - acc: 0.4736 - val_loss: 1.2544 - val_acc: 0.4843
# Epoch 10/10
#  - 18s - loss: 1.2732 - acc: 0.4774 - val_loss: 1.2280 - val_acc: 0.4956
# 30131/30131 [==============================] - 1s 17us/step
# score is  0.8559750152557632 classification accuracy is  62.32451623796701
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_53 (Reshape)         (None, 128, 2, 1)         0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 128, 2, 64)        256
# _________________________________________________________________
# dropout_23 (Dropout)         (None, 128, 2, 64)        0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 128, 2, 16)        6160
# _________________________________________________________________
# dropout_24 (Dropout)         (None, 128, 2, 16)        0
# _________________________________________________________________
# flatten_12 (Flatten)         (None, 4096)              0
# _________________________________________________________________
# dense_146 (Dense)            (None, 128)               524416
# _________________________________________________________________
# dense_147 (Dense)            (None, 10)                1290
# =================================================================
# Total params: 532,122
# Trainable params: 532,122
# Non-trainable params: 0
# _________________________________________________________________
# Train on 570000 samples, validate on 30000 samples
# Epoch 1/10
#  - 22s - loss: 1.9081 - acc: 0.2395 - val_loss: 1.6962 - val_acc: 0.3219
# Epoch 2/10
#  - 16s - loss: 1.5776 - acc: 0.3651 - val_loss: 1.4635 - val_acc: 0.4014
# Epoch 3/10
#  - 16s - loss: 1.4658 - acc: 0.4057 - val_loss: 1.4251 - val_acc: 0.4178
# Epoch 4/10
#  - 16s - loss: 1.4119 - acc: 0.4260 - val_loss: 1.3450 - val_acc: 0.4576
# Epoch 5/10
#  - 16s - loss: 1.3585 - acc: 0.4473 - val_loss: 1.3186 - val_acc: 0.4466
# Epoch 6/10
#  - 16s - loss: 1.3363 - acc: 0.4555 - val_loss: 1.3118 - val_acc: 0.4585
# Epoch 7/10
#  - 16s - loss: 1.3194 - acc: 0.4604 - val_loss: 1.2781 - val_acc: 0.4737
# Epoch 8/10
#  - 16s - loss: 1.3044 - acc: 0.4664 - val_loss: 1.2639 - val_acc: 0.4841
# Epoch 9/10
#  - 16s - loss: 1.2891 - acc: 0.4720 - val_loss: 1.2484 - val_acc: 0.4853
# Epoch 10/10
#  - 16s - loss: 1.2755 - acc: 0.4772 - val_loss: 1.2295 - val_acc: 0.4915
# 29983/29983 [==============================] - 0s 11us/step
# score is  0.6949261240674811 classification accuracy is  68.0485608427996
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_54 (Reshape)         (None, 128, 2, 1)         0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 128, 2, 64)        256
# _________________________________________________________________
# dropout_25 (Dropout)         (None, 128, 2, 64)        0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 128, 2, 16)        6160
# _________________________________________________________________
# dropout_26 (Dropout)         (None, 128, 2, 16)        0
# _________________________________________________________________
# flatten_13 (Flatten)         (None, 4096)              0
# _________________________________________________________________
# dense_148 (Dense)            (None, 128)               524416
# _________________________________________________________________
# dense_149 (Dense)            (None, 10)                1290
# =================================================================
# Total params: 532,122
# Trainable params: 532,122
# Non-trainable params: 0
# _________________________________________________________________
# Train on 570000 samples, validate on 30000 samples
# Epoch 1/10
#  - 22s - loss: 1.9278 - acc: 0.2394 - val_loss: 1.6448 - val_acc: 0.3457
# Epoch 2/10
#  - 18s - loss: 1.5141 - acc: 0.3933 - val_loss: 1.4059 - val_acc: 0.4328
# Epoch 3/10
#  - 18s - loss: 1.4173 - acc: 0.4253 - val_loss: 1.3677 - val_acc: 0.4384
# Epoch 4/10
#  - 18s - loss: 1.3793 - acc: 0.4372 - val_loss: 1.3223 - val_acc: 0.4636
# Epoch 5/10
#  - 18s - loss: 1.3468 - acc: 0.4495 - val_loss: 1.2901 - val_acc: 0.4761
# Epoch 6/10
#  - 18s - loss: 1.3215 - acc: 0.4592 - val_loss: 1.2744 - val_acc: 0.4654
# Epoch 7/10
#  - 18s - loss: 1.3033 - acc: 0.4659 - val_loss: 1.2502 - val_acc: 0.4812
# Epoch 8/10
#  - 18s - loss: 1.2864 - acc: 0.4717 - val_loss: 1.2368 - val_acc: 0.4952
# Epoch 9/10
#  - 18s - loss: 1.2729 - acc: 0.4768 - val_loss: 1.2205 - val_acc: 0.4932
# Epoch 10/10
#  - 18s - loss: 1.2618 - acc: 0.4809 - val_loss: 1.2208 - val_acc: 0.4979
# 30047/30047 [==============================] - 0s 16us/step
# score is  0.6152024957611346 classification accuracy is  70.9488467806829
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_55 (Reshape)         (None, 128, 2, 1)         0
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 128, 2, 64)        256
# _________________________________________________________________
# dropout_27 (Dropout)         (None, 128, 2, 64)        0
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 128, 2, 16)        6160
# _________________________________________________________________
# dropout_28 (Dropout)         (None, 128, 2, 16)        0
# _________________________________________________________________
# flatten_14 (Flatten)         (None, 4096)              0
# _________________________________________________________________
# dense_150 (Dense)            (None, 128)               524416
# _________________________________________________________________
# dense_151 (Dense)            (None, 10)                1290
# =================================================================
# Total params: 532,122
# Trainable params: 532,122
# Non-trainable params: 0
# _________________________________________________________________
# Train on 570000 samples, validate on 30000 samples
# Epoch 1/10
#  - 22s - loss: 1.8949 - acc: 0.2454 - val_loss: 1.6534 - val_acc: 0.3227
# Epoch 2/10
#  - 18s - loss: 1.6128 - acc: 0.3454 - val_loss: 1.4899 - val_acc: 0.4071
# Epoch 3/10
#  - 18s - loss: 1.4720 - acc: 0.4064 - val_loss: 1.4272 - val_acc: 0.4216
# Epoch 4/10
#  - 18s - loss: 1.4064 - acc: 0.4302 - val_loss: 1.3337 - val_acc: 0.4613
# Epoch 5/10
#  - 18s - loss: 1.3542 - acc: 0.4494 - val_loss: 1.2943 - val_acc: 0.4630
# Epoch 6/10
#  - 18s - loss: 1.3192 - acc: 0.4613 - val_loss: 1.2871 - val_acc: 0.4666
# Epoch 7/10
#  - 18s - loss: 1.3037 - acc: 0.4650 - val_loss: 1.2581 - val_acc: 0.4782
# Epoch 8/10
#  - 18s - loss: 1.2920 - acc: 0.4700 - val_loss: 1.2582 - val_acc: 0.4842
# Epoch 9/10
#  - 18s - loss: 1.2830 - acc: 0.4735 - val_loss: 1.2393 - val_acc: 0.4890
# Epoch 10/10
#  - 18s - loss: 1.2731 - acc: 0.4773 - val_loss: 1.2281 - val_acc: 0.4969
# 29839/29839 [==============================] - 0s 14us/step
# score is  0.6065603169544265 classification accuracy is  71.52049331212157
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_56 (Reshape)         (None, 128, 2, 1)         0
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 128, 2, 64)        256
# _________________________________________________________________
# dropout_29 (Dropout)         (None, 128, 2, 64)        0
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 128, 2, 16)        6160
# _________________________________________________________________
# dropout_30 (Dropout)         (None, 128, 2, 16)        0
# _________________________________________________________________
# flatten_15 (Flatten)         (None, 4096)              0
# _________________________________________________________________
# dense_152 (Dense)            (None, 128)               524416
# _________________________________________________________________
# dense_153 (Dense)            (None, 10)                1290
# =================================================================
# Total params: 532,122
# Trainable params: 532,122
# Non-trainable params: 0
# _________________________________________________________________
# Train on 570000 samples, validate on 30000 samples
# Epoch 1/10
#  - 22s - loss: 1.9057 - acc: 0.2435 - val_loss: 1.6415 - val_acc: 0.3378
# Epoch 2/10
#  - 16s - loss: 1.5525 - acc: 0.3759 - val_loss: 1.4391 - val_acc: 0.4152
# Epoch 3/10
#  - 16s - loss: 1.4378 - acc: 0.4185 - val_loss: 1.3705 - val_acc: 0.4415
# Epoch 4/10
#  - 16s - loss: 1.3931 - acc: 0.4357 - val_loss: 1.3282 - val_acc: 0.4638
# Epoch 5/10
#  - 16s - loss: 1.3597 - acc: 0.4480 - val_loss: 1.3069 - val_acc: 0.4699
# Epoch 6/10
#  - 16s - loss: 1.3421 - acc: 0.4538 - val_loss: 1.3038 - val_acc: 0.4624
# Epoch 7/10
#  - 16s - loss: 1.3267 - acc: 0.4590 - val_loss: 1.2843 - val_acc: 0.4700
# Epoch 8/10
#  - 16s - loss: 1.3139 - acc: 0.4621 - val_loss: 1.2838 - val_acc: 0.4721
# Epoch 9/10
#  - 16s - loss: 1.3043 - acc: 0.4656 - val_loss: 1.2810 - val_acc: 0.4686
# Epoch 10/10
#  - 16s - loss: 1.2948 - acc: 0.4686 - val_loss: 1.2538 - val_acc: 0.4777
# 30033/30033 [==============================] - 0s 7us/step
# score is  0.6317398910481498 classification accuracy is  69.34705159366696
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_57 (Reshape)         (None, 128, 2, 1)         0
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 128, 2, 64)        256
# _________________________________________________________________
# dropout_31 (Dropout)         (None, 128, 2, 64)        0
# _________________________________________________________________
# conv2d_32 (Conv2D)           (None, 128, 2, 16)        6160
# _________________________________________________________________
# dropout_32 (Dropout)         (None, 128, 2, 16)        0
# _________________________________________________________________
# flatten_16 (Flatten)         (None, 4096)              0
# _________________________________________________________________
# dense_154 (Dense)            (None, 128)               524416
# _________________________________________________________________
# dense_155 (Dense)            (None, 10)                1290
# =================================================================
# Total params: 532,122
# Trainable params: 532,122
# Non-trainable params: 0
# _________________________________________________________________
# Train on 570000 samples, validate on 30000 samples
# Epoch 1/10
#  - 22s - loss: 1.9167 - acc: 0.2398 - val_loss: 1.6785 - val_acc: 0.3143
# Epoch 2/10
#  - 18s - loss: 1.6021 - acc: 0.3525 - val_loss: 1.4745 - val_acc: 0.4045
# Epoch 3/10
#  - 18s - loss: 1.4671 - acc: 0.4088 - val_loss: 1.3995 - val_acc: 0.4384
# Epoch 4/10
#  - 18s - loss: 1.4009 - acc: 0.4336 - val_loss: 1.3454 - val_acc: 0.4475
# Epoch 5/10
#  - 18s - loss: 1.3626 - acc: 0.4475 - val_loss: 1.3116 - val_acc: 0.4711
# Epoch 6/10
#  - 18s - loss: 1.3404 - acc: 0.4553 - val_loss: 1.3032 - val_acc: 0.4698
# Epoch 7/10
#  - 18s - loss: 1.3213 - acc: 0.4628 - val_loss: 1.2788 - val_acc: 0.4787
# Epoch 8/10
#  - 18s - loss: 1.3055 - acc: 0.4692 - val_loss: 1.2667 - val_acc: 0.4883
# Epoch 9/10
#  - 18s - loss: 1.2898 - acc: 0.4736 - val_loss: 1.2520 - val_acc: 0.4932
# Epoch 10/10
#  - 18s - loss: 1.2779 - acc: 0.4779 - val_loss: 1.2426 - val_acc: 0.4939
# 29884/29884 [==============================] - 0s 13us/step
# score is  0.6126521873738995 classification accuracy is  71.77753981984199
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_58 (Reshape)         (None, 128, 2, 1)         0
# _________________________________________________________________
# conv2d_33 (Conv2D)           (None, 128, 2, 64)        256
# _________________________________________________________________
# dropout_33 (Dropout)         (None, 128, 2, 64)        0
# _________________________________________________________________
# conv2d_34 (Conv2D)           (None, 128, 2, 16)        6160
# _________________________________________________________________
# dropout_34 (Dropout)         (None, 128, 2, 16)        0
# _________________________________________________________________
# flatten_17 (Flatten)         (None, 4096)              0
# _________________________________________________________________
# dense_156 (Dense)            (None, 128)               524416
# _________________________________________________________________
# dense_157 (Dense)            (None, 10)                1290
# =================================================================
# Total params: 532,122
# Trainable params: 532,122
# Non-trainable params: 0
# _________________________________________________________________
# Train on 570000 samples, validate on 30000 samples
# Epoch 1/10
#  - 22s - loss: 1.9092 - acc: 0.2397 - val_loss: 1.6708 - val_acc: 0.3183
# Epoch 2/10
#  - 18s - loss: 1.5829 - acc: 0.3609 - val_loss: 1.4524 - val_acc: 0.4179
# Epoch 3/10
#  - 18s - loss: 1.4573 - acc: 0.4103 - val_loss: 1.4125 - val_acc: 0.4256
# Epoch 4/10
#  - 18s - loss: 1.4179 - acc: 0.4258 - val_loss: 1.3505 - val_acc: 0.4565
# Epoch 5/10
#  - 18s - loss: 1.3581 - acc: 0.4502 - val_loss: 1.3114 - val_acc: 0.4667
# Epoch 6/10
#  - 18s - loss: 1.3305 - acc: 0.4593 - val_loss: 1.2934 - val_acc: 0.4760
# Epoch 7/10
#  - 18s - loss: 1.3089 - acc: 0.4668 - val_loss: 1.2637 - val_acc: 0.4832
# Epoch 8/10
#  - 18s - loss: 1.2925 - acc: 0.4715 - val_loss: 1.2508 - val_acc: 0.4894
# Epoch 9/10
#  - 18s - loss: 1.2788 - acc: 0.4758 - val_loss: 1.2457 - val_acc: 0.4907
# Epoch 10/10
#  - 18s - loss: 1.2634 - acc: 0.4818 - val_loss: 1.2172 - val_acc: 0.4947
# 29950/29950 [==============================] - 0s 14us/step
# score is  0.5767559673033891 classification accuracy is  72.00333887388392
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_59 (Reshape)         (None, 128, 2, 1)         0
# _________________________________________________________________
# conv2d_35 (Conv2D)           (None, 128, 2, 64)        256
# _________________________________________________________________
# dropout_35 (Dropout)         (None, 128, 2, 64)        0
# _________________________________________________________________
# conv2d_36 (Conv2D)           (None, 128, 2, 16)        6160
# _________________________________________________________________
# dropout_36 (Dropout)         (None, 128, 2, 16)        0
# _________________________________________________________________
# flatten_18 (Flatten)         (None, 4096)              0
# _________________________________________________________________
# dense_158 (Dense)            (None, 128)               524416
# _________________________________________________________________
# dense_159 (Dense)            (None, 10)                1290
# =================================================================
# Total params: 532,122
# Trainable params: 532,122
# Non-trainable params: 0
# _________________________________________________________________
# Train on 570000 samples, validate on 30000 samples
# Epoch 1/10
#  - 22s - loss: 1.9127 - acc: 0.2394 - val_loss: 1.6752 - val_acc: 0.3190
# Epoch 2/10
#  - 18s - loss: 1.5809 - acc: 0.3625 - val_loss: 1.4355 - val_acc: 0.4274
# Epoch 3/10
#  - 18s - loss: 1.4329 - acc: 0.4220 - val_loss: 1.3678 - val_acc: 0.4421
# Epoch 4/10
#  - 18s - loss: 1.3791 - acc: 0.4413 - val_loss: 1.3283 - val_acc: 0.4606
# Epoch 5/10
#  - 18s - loss: 1.3446 - acc: 0.4530 - val_loss: 1.3042 - val_acc: 0.4739
# Epoch 6/10
#  - 18s - loss: 1.3229 - acc: 0.4599 - val_loss: 1.2701 - val_acc: 0.4867
# Epoch 7/10
#  - 18s - loss: 1.3034 - acc: 0.4674 - val_loss: 1.2610 - val_acc: 0.4874
# Epoch 8/10
#  - 18s - loss: 1.2884 - acc: 0.4723 - val_loss: 1.2506 - val_acc: 0.4874
# Epoch 9/10
#  - 18s - loss: 1.2759 - acc: 0.4769 - val_loss: 1.2365 - val_acc: 0.4884
# Epoch 10/10
#  - 18s - loss: 1.2652 - acc: 0.4798 - val_loss: 1.2217 - val_acc: 0.4976
# 30055/30055 [==============================] - 1s 17us/step
# score is  0.5971279019643891 classification accuracy is  71.61537182031624
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_60 (Reshape)         (None, 128, 2, 1)         0
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, 128, 2, 64)        256
# _________________________________________________________________
# dropout_37 (Dropout)         (None, 128, 2, 64)        0
# _________________________________________________________________
# conv2d_38 (Conv2D)           (None, 128, 2, 16)        6160
# _________________________________________________________________
# dropout_38 (Dropout)         (None, 128, 2, 16)        0
# _________________________________________________________________
# flatten_19 (Flatten)         (None, 4096)              0
# _________________________________________________________________
# dense_160 (Dense)            (None, 128)               524416
# _________________________________________________________________
# dense_161 (Dense)            (None, 10)                1290
# =================================================================
# Total params: 532,122
# Trainable params: 532,122
# Non-trainable params: 0
# _________________________________________________________________
# Train on 570000 samples, validate on 30000 samples
# Epoch 1/10
#  - 20s - loss: 1.9096 - acc: 0.2415 - val_loss: 1.6214 - val_acc: 0.3454
# Epoch 2/10
#  - 16s - loss: 1.5365 - acc: 0.3823 - val_loss: 1.4462 - val_acc: 0.4136
# Epoch 3/10
#  - 16s - loss: 1.4522 - acc: 0.4125 - val_loss: 1.3946 - val_acc: 0.4386
# Epoch 4/10
#  - 16s - loss: 1.4187 - acc: 0.4253 - val_loss: 1.3724 - val_acc: 0.4409
# Epoch 5/10
#  - 16s - loss: 1.3965 - acc: 0.4342 - val_loss: 1.3564 - val_acc: 0.4407
# Epoch 6/10
#  - 16s - loss: 1.3601 - acc: 0.4477 - val_loss: 1.3012 - val_acc: 0.4626
# Epoch 7/10
#  - 16s - loss: 1.3230 - acc: 0.4617 - val_loss: 1.2742 - val_acc: 0.4774
# Epoch 8/10
#  - 16s - loss: 1.3020 - acc: 0.4679 - val_loss: 1.2623 - val_acc: 0.4767
# Epoch 9/10
#  - 16s - loss: 1.2874 - acc: 0.4732 - val_loss: 1.2408 - val_acc: 0.4941
# Epoch 10/10
#  - 16s - loss: 1.2766 - acc: 0.4767 - val_loss: 1.2309 - val_acc: 0.4882
# 29828/29828 [==============================] - 0s 10us/step
# score is  0.5983643967264121 classification accuracy is  70.48410888058388
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_61 (Reshape)         (None, 128, 2, 1)         0
# _________________________________________________________________
# conv2d_39 (Conv2D)           (None, 128, 2, 64)        256
# _________________________________________________________________
# dropout_39 (Dropout)         (None, 128, 2, 64)        0
# _________________________________________________________________
# conv2d_40 (Conv2D)           (None, 128, 2, 16)        6160
# _________________________________________________________________
# dropout_40 (Dropout)         (None, 128, 2, 16)        0
# _________________________________________________________________
# flatten_20 (Flatten)         (None, 4096)              0
# _________________________________________________________________
# dense_162 (Dense)            (None, 128)               524416
# _________________________________________________________________
# dense_163 (Dense)            (None, 10)                1290
# =================================================================
# Total params: 532,122
# Trainable params: 532,122
# Non-trainable params: 0
# _________________________________________________________________
# Train on 570000 samples, validate on 30000 samples
# Epoch 1/10
#  - 20s - loss: 1.9322 - acc: 0.2371 - val_loss: 1.6743 - val_acc: 0.3151
# Epoch 2/10
#  - 16s - loss: 1.6355 - acc: 0.3350 - val_loss: 1.5063 - val_acc: 0.3972
# Epoch 3/10
#  - 16s - loss: 1.4844 - acc: 0.4008 - val_loss: 1.4077 - val_acc: 0.4277
# Epoch 4/10
#  - 16s - loss: 1.4294 - acc: 0.4199 - val_loss: 1.3715 - val_acc: 0.4441
# Epoch 5/10
#  - 16s - loss: 1.3870 - acc: 0.4354 - val_loss: 1.3393 - val_acc: 0.4477
# Epoch 6/10
#  - 16s - loss: 1.3650 - acc: 0.4427 - val_loss: 1.3221 - val_acc: 0.4605
# Epoch 7/10
#  - 16s - loss: 1.3392 - acc: 0.4538 - val_loss: 1.2952 - val_acc: 0.4730
# Epoch 8/10
#  - 16s - loss: 1.3219 - acc: 0.4592 - val_loss: 1.2780 - val_acc: 0.4735
# Epoch 9/10
#  - 16s - loss: 1.3109 - acc: 0.4621 - val_loss: 1.2702 - val_acc: 0.4819
# Epoch 10/10
#  - 16s - loss: 1.3017 - acc: 0.4652 - val_loss: 1.2658 - val_acc: 0.4734
# 30013/30013 [==============================] - 0s 12us/step
# score is  0.6451070877524085 classification accuracy is  67.96721421909265
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_62 (Reshape)         (None, 128, 2, 1)         0
# _________________________________________________________________
# conv2d_41 (Conv2D)           (None, 128, 2, 64)        256
# _________________________________________________________________
# dropout_41 (Dropout)         (None, 128, 2, 64)        0
# _________________________________________________________________
# conv2d_42 (Conv2D)           (None, 128, 2, 16)        6160
# _________________________________________________________________
# dropout_42 (Dropout)         (None, 128, 2, 16)        0
# _________________________________________________________________
# flatten_21 (Flatten)         (None, 4096)              0
# _________________________________________________________________
# dense_164 (Dense)            (None, 128)               524416
# _________________________________________________________________
# dense_165 (Dense)            (None, 10)                1290
# =================================================================
# Total params: 532,122
# Trainable params: 532,122
# Non-trainable params: 0
# _________________________________________________________________
# Train on 570000 samples, validate on 30000 samples
# Epoch 1/10
#  - 20s - loss: 1.9666 - acc: 0.2247 - val_loss: 1.6911 - val_acc: 0.3130
# Epoch 2/10
#  - 16s - loss: 1.6039 - acc: 0.3511 - val_loss: 1.4537 - val_acc: 0.4135
# Epoch 3/10
#  - 16s - loss: 1.4681 - acc: 0.4051 - val_loss: 1.3992 - val_acc: 0.4304
# Epoch 4/10
#  - 16s - loss: 1.4203 - acc: 0.4240 - val_loss: 1.3597 - val_acc: 0.4511
# Epoch 5/10
#  - 16s - loss: 1.3701 - acc: 0.4437 - val_loss: 1.3085 - val_acc: 0.4638
# Epoch 6/10
#  - 16s - loss: 1.3346 - acc: 0.4569 - val_loss: 1.2836 - val_acc: 0.4842
# Epoch 7/10
#  - 16s - loss: 1.3137 - acc: 0.4651 - val_loss: 1.2696 - val_acc: 0.4825
# Epoch 8/10
#  - 16s - loss: 1.2982 - acc: 0.4707 - val_loss: 1.2560 - val_acc: 0.4868
# Epoch 9/10
#  - 16s - loss: 1.2856 - acc: 0.4737 - val_loss: 1.2451 - val_acc: 0.4873
# Epoch 10/10
#  - 16s - loss: 1.2737 - acc: 0.4777 - val_loss: 1.2309 - val_acc: 0.4964
# 30082/30082 [==============================] - 0s 13us/step
# score is  0.5932726582292943 classification accuracy is  72.1461338796686
# The average overall accuracy is 0.4914443261132286
